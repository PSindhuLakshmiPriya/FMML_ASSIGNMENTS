# %% [markdown]
# <a href="https://colab.research.google.com/github/PSindhuLakshmiPriya/FMML_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 16:42:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   259MB/s    in 0.3s
#
# 2024-03-28 16:42:11 (259 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22069   1409.7193v2  Significant attention has been given to minimi...  stat
# 121    1711.11486v1  In statistical dialogue management, the dialog...  stat
# 32585   1404.4114v3  Stochastic variational inference makes it poss...    cs
# 30301  1711.10775v1  Approximate nearest neighbor (ANN) search has ...    cs
# 26170  1609.01371v2  Although commercial and open-source software e...    cs
# ...             ...                                                ...   ...
# 33553   1003.3676v2  We propose simple heuristics for the assembly ...    cs
# 865    1502.04434v3  In many classification problems a classifier s...  stat
# 19976   1303.5730v1  This paper outlines a methodology for analyzin...    cs
# 31944   1301.6659v4  Recommender systems are emerging technologies ...    cs
# 37872   1006.0868v2  The Gaussian process (GP) is a popular way to ...  stat
#
#                                                    title  year  \
# 22069    MIST: L0 Sparse Linear Regression with Momentum  2014
# 121    Uncertainty Estimates for Efficient Neural Net...  2017
# 32585        Structured Stochastic Variational Inference  2014
# 30301                        Online Product Quantization  2017
# 26170  Reconstructing Articulated Rigged Models from ...  2016
# ...                                                  ...   ...
# 33553  Simple heuristics for the assembly line worker...  2010
# 865    Invariant backpropagation: how to train a tran...  2015
# 19976  Representation Requirements for Supporting Dec...  2013
# 31944              Clustering-Based Matrix Factorization  2013
# 37872  Slice sampling covariance hyperparameters of l...  2010
#
#                                                 keywords
# 22069  [significant, attention, minimizing, penalized...
# 121    [statistical, management, efficient, explorati...
# 32585  [stochastic, variational, inference, approxima...
# 30301  [approximate, quantization, databases, distrib...
# 26170  [commercial, reconstruct, articulated, realist...
# ...                                                  ...
# 33553  [heuristics, assignment, balancing, typically,...
# 865    [classification, classifier, variations, parti...
# 19976  [methodology, analyzing, representational, kno...
# 31944  [recommender, technologies, applications, info...
# 37872  [dependencies, variables, probabilistic, frame...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22069    [significant, attention, minimizing, penalized...
# 121      [statistical, management, efficient, explorati...
# 32585    [stochastic, variational, inference, approxima...
# 30301    [approximate, quantization, databases, distrib...
# 26170    [commercial, reconstruct, articulated, realist...
#                                ...
# 859      [auxiliary, stochastic, perceptron, generaliza...
# 39682    [representation, population, efficient, repres...
# 22366    [investigations, performed, clustering, commer...
# 30214    [information, approaches, generalizable, repre...
# 32190    [customers, underlying, formulated, dependent,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8848 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e1e8e127-63b9-4822-a8b8-6560af3f363b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1e8e127-63b9-4822-a8b8-6560af3f363b")) {                    Plotly.newPlot(                        "e1e8e127-63b9-4822-a8b8-6560af3f363b",                        [{"x":["simulations","significant","resulting","solutions","estimating","shrinkage","algorithm","regression","convergence","iterative","responsible","minimizer","criterion","minimizing","penalized","equations","attention","thresholding","performance","alternative","variation","reinforcement","successful","benchmark","estimates","extensive","uncertainties","optimisation","exploration","combining","efficient","promising","management","divergences","experience","uncertainty","approaches","computational","bootstrapped","subjecting","statistical","complexity","distributions","structured","independence","arbitrary","variables","posterior","optimization","parameter","stochastic","variational","dependencies","parameters","hyperparameters","approximation","introduces","producing","approximate","factorized","inference","sensitivity","incrementally","behaviour","alleviate","retraining","computation","guarantees","accommodates","furthermore","demonstrate","distribution","quantization","effective","developing","dynamically","insertion","databases","experiments","supported","streaming","constraints","clustering","commercial","curvature","reconstructing","deformable","realistically","articulated","animation","segmentation","reconstruct","positions","manipulate","acquisition","sufficiently","environment","automatically","controller","automated","representation","framework","visuomotor","continuously","configuration","automates","including","autoencoder","construction","autoencoders","proliferation","fragments","different","potential","embeddings","detection","distinguishing","evaluation","community","constantly","automatic","potentially","knowledge","answering","reliability","optimality","generalized","applications","additional","technical","conditional","introduced","discussed","objective","objectives","certificate","reconstruction","selecting","eliminates","documents","conventional","integrated","utilization","carefully","conditioning","condition","beneficial","deblurring","technique","available","illumination","compressed","predictors","excellent","significance","estimation","algorithms","coherence","expensive","approximations","corroborate","efficiently","practical","following","effectiveness","considered","characterize","experimental","synthetic","information","theoretical","accurately","introducing","principal","representations","discovery","challenges","intrinsic","functions","traditional","directions","consideration","discovered","laplacian","environments","implicitly","implement","sensitive","processing","cognitive","convolutional","constrained","hippocampal","consequences","artificial","modulation","mechanism","contextual","formation","implicated"],"y":[43,237,149,140,63,3,752,119,100,84,13,2,45,42,0,27,185,19,909,93,58,107,77,233,60,159,9,17,57,95,443,129,42,5,46,92,450,283,4,1,151,217,97,112,37,82,137,36,324,111,131,68,49,238,17,114,80,29,128,11,224,29,19,30,29,6,135,62,3,166,557,201,14,246,66,29,5,57,622,20,16,152,133,20,12,17,11,5,6,4,230,30,26,8,44,21,131,196,29,110,370,566,2,17,19,3,247,32,81,24,10,7,742,154,71,355,10,270,66,6,199,39,346,68,32,28,64,433,112,37,101,132,60,165,39,1,112,43,12,62,113,65,10,28,20,54,25,7,249,309,36,30,15,33,13,193,583,12,64,39,3,137,128,77,208,126,40,391,136,701,145,58,50,31,229,65,116,41,212,172,41,29,22,15,87,20,70,61,295,51,403,60,3,14,116,1,111,51,12,1],"type":"bar"},{"x":["simulations","significant","resulting","solutions","estimating","shri ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8241666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Space</span> <span style=''>Time</span> <span style='background-color:rgba(0, 255, 0, 0.3883677298311444);'>Representation</span> <span style=''>of</span> <span style=''>People</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>3D</span> <span style=''>Skeletal</span> <span style=''>Data</span> <span style=''>A</span> <span style=''>Review</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Spatiotemporal</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.3883677298311444);'>representation</span> <span style=''>based</span> <span style=''>on</span> <span style=''>3D</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529412);'>perception</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style=''>rapidly</span> <span style=''>growing</span> <span style=''>research</span> <span style=''>area</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>sources</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3550295857988166);'>representations</span> <span style=''>can</span> <span style=''>be</span> <span style=''>broadly</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>categorized</span> <span style=''>into</span> <span style=''>two</span> <span style=''>groups</span> <span style=''>based</span> <span style=''>on</span> <span style=''>RGB</span> <span style=''>D</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>or</span> <span style=''>3D</span> <span style=''>skeleton</span> <span style=''>data</span> <span style=''>Recently</span> <span style=''>skeleton</span> <span style=''>based</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.3550295857988166);'>representations</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensively</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>kept</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>attracting</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style='background-color:rgba(0, 255, 0, 0.40684410646387836);'>attention</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.6041666666666665);'>variations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>viewpoint</span> <span style=''>human</span> <span style=''>body</span> <span style=''>scale</span> <span style=''>and</span> <span style=''>motion</span> <span style=''>speed</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style=''>realtime</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5604395604395604);'>comprehensive</span> <span style=''>survey</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>space</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3550295857988166);'>representations</span> <span style=''>of</span> <span style=''>people</span> <span style=''>based</span> <span style=''>on</span> <span style=''>3D</span> <span style=''>skeletal</span> <span style=''>data</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inf ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>Bayesian</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>Recovery</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>seen</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>activity</span> <span style=''>in</span> <span style=''>many</span> <span style=''>areas</span> <span style=''>of</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>results</span> <span style=''>for</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>this</span> <span style=''>recovery</span> <span style=''>problem</span> <span style=''>However</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style=''>method</span> <span style=''>for</span> <span style=''>choosing</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>target</span> <span style=''>rank</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>not</span> <span style=''>provided</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>novel</span> <span style=''>recovery</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>in</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>and</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>based</span> <span style=''>on</span> <span style=''>sparse</span> <span style=''>Bayesian</span> <span style=''>learning</span> <span style=''>(SBL)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>Starting</span> <span style=''>from</span> <span style=''>a</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enforcing</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.46774193548387094);'>Parametric</span> <span style=''>Output</span> <span style=''>HMMs</span> <span style=''>with</span> <span style=''>Two</span> <span style=''>Aliased</span> <span style=''>States</span> <br/><br/><span style=''>In</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>models</span> <span style=''>(HMMs)</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>states</span> <span style=''>are</span> <span style=''>aliased</span> <span style=''>having</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.4260355029585799);'>distributions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>minimality</span> <span style='background-color:rgba(255, 0, 0, 0.7037037037037037);'>identifiability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>learnability</span> <span style=''>of</span> <span style=''>such</span> <span style=''>aliased</span> <span style=''>HMMs</span> <span style=''>have</span> <span style=''>been</span> <span style=''>long</span> <span style=''>standing</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>only</span> <span style=''>partial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>provided</span> <span style=''>thus</span> <span style=''>far</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.46774193548387094);'>parametric</span> <span style=''>output</span> <span style=''>HMMs</span> <span style=''>whose</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.4260355029585799);'>distributions</span> <span style=''>come</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.46774193548387094);'>parametric</span> <span style=''>family</span> <span style=''>and</span> <span style=''>that</span> <span style=''>have</span> <span style=''>exactly</span> <span style=''>two</span> <span style=''>aliased</span> <span style=''>states</span> <span style=''>For</span> <span style=''>this</span> <span style=''>class</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>complete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>minimality</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.7037037037037037);'>identifiability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>for</span> <span style=''>a</span> <span style=''>large</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.46774193548387094);'>parametric</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.4260355029585799);'>distributions</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>THAP</span> <span style=''>A</span> <span style=''>Matlab</span> <span style=''>Toolkit</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Hawkes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>As</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asynchronous</span> <span style=''>event</span> <span style=''>sequence</span> <span style=''>analysis</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>have</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>for</span> <span style=''>a</span> <span style=''>long</span> <span style=''>time</span> <span style=''>and</span> <span style=''>achieved</span> <span style=''>numerous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successes</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>fields</span> <span style=''>Among</span> <span style=''>various</span> <span style=''>point</span> <span style=''>process</span> <span style=''>models</span> <span style=''>Hawkes</span> <span style=''>process</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>attract</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>these</span> <span style=''>years</span> <span style=''>because</span> <span style=''>they</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>self</span> <span style=''>and</span> <span style=''>mutually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>triggering</span> <span style=''>patterns</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>events</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitatively</span> <span style=''>and</span> <span style=''>are</span> <span style=''>broadly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>toolkit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementing</span> <span style=''>many</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>Hawkes</span> <span style=''>process</span> <span style=''>model</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>Our</span> <span style=''>toolkit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>systematically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summarizes</span> <span style=''>recent</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13999283924095954)
# 	processing (0.10562119584675976)
# 	representation (0.13247404224847834)
# 	architecture (0.08592910848549946)
# 	information (0.250984604368063)
# 	segmentation (0.08234872896527032)
# 	detection (0.12710347296813462)
# 	different (0.2656641604010025)
# 	recognition (0.13498030791263874)
# 	convolutional (0.14428929466523452)
#
# Some Statistics words are:
# 	stochastic (0.13502740408570005)
# 	statistical (0.15346287992027902)
# 	variables (0.15097159940209268)
# 	theoretical (0.15495764823119082)
# 	estimation (0.17438963627304435)
# 	inference (0.1898355754857997)
# 	distribution (0.19133034379671152)
# 	dimensional (0.1863477827603388)
# 	algorithm (0.4020926756352765)
# 	regression (0.17737917289486796)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="72ae5c61-78df-42eb-863e-b4c8f2b90d59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72ae5c61-78df-42eb-863e-b4c8f2b90d59")) {                    Plotly.newPlot(                        "72ae5c61-78df-42eb-863e-b4c8f2b90d59",                        [{"x":["simulations","significant","resulting","solutions","estimating","shrinkage","algorithm","regression","convergence","iterative","responsible","minimizer","criterion","minimizing","penalized","equations","attention","thresholding","performance","alternative","variation","reinforcement","successful","benchmark","estimates","extensive","uncertainties","optimisation","exploration","combining","efficient","promising","management","divergences","experience","uncertainty","approaches","computational","bootstrapped","subjecting","statistical","complexity","distributions","structured","independence","arbitrary","variables","posterior","optimization","parameter","stochastic","variational","dependencies","parameters","hyperparameters","approximation","introduces","producing","approximate","factorized","inference","sensitivity","incrementally","behaviour","alleviate","retraining","computation","guarantees","accommodates","furthermore","demonstrate","distribution","quantization","effective","developing","dynamically","insertion","databases","experiments","supported","streaming","constraints","clustering","commercial","curvature","reconstructing","deformable","realistically","articulated","animation","segmentation","reconstruct","positions","manipulate","acquisition","sufficiently","environment","automatically","controller","automated","representation","framework","visuomotor","continuously","configuration","automates","including","autoencoder","construction","autoencoders","proliferation","fragments","different","potential","embeddings","detection","distinguishing","evaluation","community","constantly","automatic","potentially","knowledge","answering","reliability","optimality","generalized","applications","additional","technical","conditional","introduced","discussed","objective","objectives","certificate","reconstruction","selecting","eliminates","documents","conventional","integrated","utilization","carefully","conditioning","condition","beneficial","deblurring","technique","available","illumination","compressed","predictors","excellent","significance","estimation","algorithms","coherence","expensive","approximations","corroborate","efficiently","practical","following","effectiveness","considered","characterize","experimental","synthetic","information","theoretical","accurately","introducing","principal","representations","discovery","challenges","intrinsic","functions","traditional","directions","consideration","discovered","laplacian","environments","implicitly","implement","sensitive","processing","cognitive","convolutional","constrained","hippocampal","consequences","artificial","modulation","mechanism","contextual","formation","implicated","motivation","biological","architectures","introduce","hippocampus","restriction","calculate","empirical","statistics","proposals","tractably","improving","difficult","generated","importance","calculated","implementing","identification","consisting","monotonically","increasing","classical","dynamical","estimator","indicated","contrasts","inequality","consistent","smoothness","nonlinearity","techniques","decomposition","properties","linearization","observations","quadratic","probability","semantics","intuition","classification","represent","reasonable","distributional","baselines","conducted","important","recommend","impossible","recommendation","occurrences","outperforms","probabilistic","interesting","heuristics","conjugate","reproducin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	penalized
# 	lengthscale
# 	reversing
# 	dendrograms
# 	dendrogram
# 	extrapolation
# 	trivially
# 	fibrillation
# 	specializes
# 	independences
# 	diameters
# 	marginalization
# 	multitype
# 	textitnot
# 	supernova
# 	terabytes
# 	sparsities
# 	ferromagnetic
# 	sinusoidal
# 	extrapolating
# Some words which never appear in Statistics papers:
# 	insertion
# 	deformable
# 	realistically
# 	articulated
# 	animation
# 	visuomotor
# 	deblurring
# 	illumination
# 	contrasts
# 	commensurate
# 	coordination
# 	visitation
# 	exchanged
# 	developer
# 	intentions
# 	cityscapes
# 	gyroscope
# 	accelerometer
# 	interlingual
# 	specifies

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.078249091916518e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
